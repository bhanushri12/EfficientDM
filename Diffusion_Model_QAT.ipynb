# %%
import os
import sys
import time
import numpy as np
import PIL
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import urllib
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms

# Set up warnings
import warnings
warnings.filterwarnings(
    action='ignore',
    category=DeprecationWarning,
    module=r'.*'
)
warnings.filterwarnings(
    action='default',
    module=r'torch.ao.quantization'
)

# Specify random seed for repeatable results
torch.manual_seed(191009)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
IMAGE_SHAPE = (32,32)

# %%
transform = transforms.Compose([
    transforms.Resize(IMAGE_SHAPE), # Resize the input image
    transforms.ToTensor(), # Convert to torch tensor (scales data into [0,1])
    transforms.Lambda(lambda t: (t * 2) - 1), # Scale data between [-1, 1]
])


reverse_transform = transforms.Compose([
    transforms.Lambda(lambda t: (t + 1) / 2), # Scale data between [0,1]
    transforms.Lambda(lambda t: t.permute(1, 2, 0)), # CHW to HWC
    transforms.Lambda(lambda t: t * 255.), # Scale data between [0.,255.]
    transforms.Lambda(lambda t: t.cpu().numpy().astype(np.uint8)), # Convert into an uint8 numpy array
    transforms.ToPILImage(), # Convert to PIL image
])

# %%
def get_sample_image()-> PIL.Image.Image:
    url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZmJy3aSZ1Ix573d2MlJXQowLCLQyIUsPdniOJ7rBsgG4XJb04g9ZFA9MhxYvckeKkVmo&usqp=CAU'
    filename = 'racoon.jpg'
    urllib.request.urlretrieve(url, filename)
    return PIL.Image.open(filename)

# %%
IMAGE_SHAPE = (32, 32)

# %%
pil_image = get_sample_image()
torch_image = transform(pil_image)

# %%
def plot_noise_distribution(noise, predicted_noise):
    plt.hist(noise.cpu().numpy().flatten(), density = True, alpha = 0.8, label = "ground truth noise")
    plt.hist(predicted_noise.cpu().numpy().flatten(), density = True, alpha = 0.8, label = "predicted noise")
    plt.legend()
    plt.show()

# %%
def plot_noise_prediction(noise, predicted_noise):
    plt.figure(figsize=(15,15))
    f, ax = plt.subplots(1, 2, figsize = (5,5))
    ax[0].imshow(reverse_transform(noise))
    ax[0].set_title(f"ground truth noise", fontsize = 10)
    ax[1].imshow(reverse_transform(predicted_noise))
    ax[1].set_title(f"predicted noise", fontsize = 10)
    plt.show()

# %%
class DiffusionModel:
    def __init__(self, start_schedule=0.0001, end_schedule=0.02, timesteps = 300):
        self.start_schedule = start_schedule
        self.end_schedule = end_schedule
        self.timesteps = timesteps

        """
        if
            betas = [0.1, 0.2, 0.3, ...]
        then
            alphas = [0.9, 0.8, 0.7, ...]
            alphas_cumprod = [0.9, 0.9 * 0.8, 0.9 * 0.8, * 0.7, ...]


        """
        self.betas = torch.linspace(start_schedule, end_schedule, timesteps)
        self.alphas = 1 - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)

    def forward(self, x_0, t, device):
        """
        x_0: (B, C, H, W)
        t: (B,)
        """
        noise = torch.randn_like(x_0)
        sqrt_alphas_cumprod_t = self.get_index_from_list(self.alphas_cumprod.sqrt(), t, x_0.shape)
        sqrt_one_minus_alphas_cumprod_t = self.get_index_from_list(torch.sqrt(1. - self.alphas_cumprod), t, x_0.shape)

        mean = sqrt_alphas_cumprod_t.to(device) * x_0.to(device)
        variance = sqrt_one_minus_alphas_cumprod_t.to(device) * noise.to(device)

        return mean + variance, noise.to(device)

    @torch.no_grad()
    def backward(self, x, t, model, **kwargs):
        """
        Calls the model to predict the noise in the image and returns
        the denoised image.
        Applies noise to this image, if we are not in the last step yet.
        """
        betas_t = self.get_index_from_list(self.betas, t, x.shape)
        sqrt_one_minus_alphas_cumprod_t = self.get_index_from_list(torch.sqrt(1. - self.alphas_cumprod), t, x.shape)
        sqrt_recip_alphas_t = self.get_index_from_list(torch.sqrt(1.0 / self.alphas), t, x.shape)
        mean = sqrt_recip_alphas_t * (x - betas_t * model(x, t, **kwargs) / sqrt_one_minus_alphas_cumprod_t)
        posterior_variance_t = betas_t

        if t == 0:
            return mean
        else:
            noise = torch.randn_like(x)
            variance = torch.sqrt(posterior_variance_t) * noise
            return mean + variance

    @staticmethod
    def get_index_from_list(values, t, x_shape):
        batch_size = t.shape[0]
        """
        pick the values from vals
        according to the indices stored in `t`
        """
        result = values.gather(-1, t.cpu())
        """
        if
        x_shape = (5, 3, 64, 64)
            -> len(x_shape) = 4
            -> len(x_shape) - 1 = 3

        and thus we reshape `out` to dims
        (batch_size, 1, 1, 1)

        """
        return result.reshape(batch_size, *((1,) * (len(x_shape) - 1))).to(t.device)

# %%
diffusion_model = DiffusionModel()

# %%
device = 'cpu'

# %%
import matplotlib.pyplot as plt

# %%
NO_DISPLAY_IMAGES = 5
torch_image_batch = torch.stack([torch_image] * NO_DISPLAY_IMAGES)
t = torch.linspace(0, diffusion_model.timesteps - 1, NO_DISPLAY_IMAGES).long()
noisy_image_batch, _ = diffusion_model.forward(torch_image_batch, t, device)

plt.figure(figsize=(15,15))
f, ax = plt.subplots(1, NO_DISPLAY_IMAGES, figsize = (100,100))

for idx, image in enumerate(noisy_image_batch):
    ax[idx].imshow(reverse_transform(image))
    ax[idx].set_title(f"Iteration: {t[idx].item()}", fontsize = 100)
plt.show()

# %% [markdown]
# ###Backward Denoising

# %%
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

# %%
class Block(nn.Module):
    def __init__(self, channels_in, channels_out, time_embedding_dims, labels, num_filters = 3, downsample=True):
        super().__init__()

        self.time_embedding_dims = time_embedding_dims
        self.time_embedding = SinusoidalPositionEmbeddings(time_embedding_dims)
        self.labels = labels
        if labels:
            self.label_mlp = nn.Linear(1, channels_out)

        self.downsample = downsample

        if downsample:
            self.conv1 = nn.Conv2d(channels_in, channels_out, num_filters, padding=1)
            self.final = nn.Conv2d(channels_out, channels_out, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(2 * channels_in, channels_out, num_filters, padding=1)
            self.final = nn.ConvTranspose2d(channels_out, channels_out, 4, 2, 1)

        self.bnorm1 = nn.BatchNorm2d(channels_out)
        self.bnorm2 = nn.BatchNorm2d(channels_out)

        self.conv2 = nn.Conv2d(channels_out, channels_out, 3, padding=1)
        self.time_mlp = nn.Linear(time_embedding_dims, channels_out)
        self.relu = nn.ReLU()

    def forward(self, x, t, **kwargs):
        o = self.bnorm1(self.relu(self.conv1(x)))
        o_time = self.relu(self.time_mlp(self.time_embedding(t)))
        o = o + o_time[(..., ) + (None, ) * 2]
        if self.labels:
            label = kwargs.get('labels')
            o_label = self.relu(self.label_mlp(label))
            o = o + o_label[(..., ) + (None, ) * 2]

        o = self.bnorm2(self.relu(self.conv2(o)))

        return self.final(o)

# %%
class UNet(nn.Module):
    def __init__(self, img_channels = 3, time_embedding_dims = 128, labels = False, sequence_channels = (64, 128, 256, 512, 1024)):
        super().__init__()
        self.time_embedding_dims = time_embedding_dims
        sequence_channels_rev = reversed(sequence_channels)

        self.downsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels) for channels_in, channels_out in zip(sequence_channels, sequence_channels[1:])])
        self.upsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels,downsample=False) for channels_in, channels_out in zip(sequence_channels[::-1], sequence_channels[::-1][1:])])
        self.conv1 = nn.Conv2d(img_channels, sequence_channels[0], 3, padding=1)
        self.conv2 = nn.Conv2d(sequence_channels[0], img_channels, 1)


    def forward(self, x, t, **kwargs):
        residuals = []
        o = self.conv1(x)
        for ds in self.downsampling:
            o = ds(o, t, **kwargs)
            residuals.append(o)
        for us, res in zip(self.upsampling, reversed(residuals)):
            o = us(torch.cat((o, res), dim=1), t, **kwargs)

        return self.conv2(o)

# %%
NO_EPOCHS = 2000
PRINT_FREQUENCY = 100
LR = 0.001
BATCH_SIZE = 128
VERBOSE = True

unet = UNet(labels=False)
unet.to(device='cpu')
optimizer = torch.optim.Adam(unet.parameters(), lr=LR)

# %%
for epoch in range(NO_EPOCHS):
    mean_epoch_loss = []

    batch = torch.stack([torch_image] * BATCH_SIZE)
    t = torch.randint(0, diffusion_model.timesteps, (BATCH_SIZE,)).long().to(device='cpu')

    batch_noisy, noise = diffusion_model.forward(batch, t, device='cpu')
    predicted_noise = UNet(batch_noisy, t)

    optimizer.zero_grad()
    loss = torch.nn.functional.mse_loss(noise, predicted_noise)
    mean_epoch_loss.append(loss.item())
    loss.backward()
    optimizer.step()

    if epoch % PRINT_FREQUENCY == 0:
        print('---')
        print(f"Epoch: {epoch} | Train Loss {np.mean(mean_epoch_loss)}")
        if VERBOSE:
            with torch.no_grad():
                plot_noise_prediction(noise[0], predicted_noise[0])
                plot_noise_distribution(noise, predicted_noise)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-c2fc028569ec> in <cell line: 1>()
#       6
#       7     batch_noisy, noise = diffusion_model.forward(batch, t, device='cpu')
# ----> 8     predicted_noise = myModel(batch_noisy, t)
#       9
#      10     optimizer.zero_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
import math
with torch.no_grad():
    img = torch.randn((1, 3) + IMAGE_SHAPE).to(device)
    for i in reversed(range(diffusion_model.timesteps)):
        t = torch.full((1,), i, dtype=torch.long, device=device)
        img = diffusion_model.backward(img, t, unet.eval())
        if i % 50 == 0:
            plt.figure(figsize=(2,2))
            plt.imshow(reverse_transform(img[0]))
            plt.show()

# %%
BATCH_SIZE = 256
NO_EPOCHS = 2
PRINT_FREQUENCY = 10
LR = 0.001
VERBOSE = False

unet = UNet(labels=True)
unet.to(device)
optimizer = torch.optim.Adam(unet.parameters(), lr=LR)

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8, drop_last=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=8, drop_last=True)
# Out:
# ...
# 100%|██████████| 170M/170M [00:02<00:00, 74.2MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Files already downloaded and verified

# %%
for epoch in range(NO_EPOCHS):
    mean_epoch_loss = []
    mean_epoch_loss_val = []
    for batch, label in trainloader:
        t = torch.randint(0, diffusion_model.timesteps, (BATCH_SIZE,)).long().to(device)
        batch = batch.to(device)
        batch_noisy, noise = diffusion_model.forward(batch, t, device)
        predicted_noise = unet(batch_noisy, t, labels = label.reshape(-1,1).float().to(device))

        optimizer.zero_grad()
        loss = torch.nn.functional.mse_loss(noise, predicted_noise)
        mean_epoch_loss.append(loss.item())
        loss.backward()
        optimizer.step()

    for batch, label in testloader:

        t = torch.randint(0, diffusion_model.timesteps, (BATCH_SIZE,)).long().to(device)
        batch = batch.to(device)

        batch_noisy, noise = diffusion_model.forward(batch, t, device)
        predicted_noise = unet(batch_noisy, t, labels = label.reshape(-1,1).float().to(device))

        loss = torch.nn.functional.mse_loss(noise, predicted_noise)
        mean_epoch_loss_val.append(loss.item())

    if epoch % PRINT_FREQUENCY == 0:
        print('---')
        print(f"Epoch: {epoch} | Train Loss {np.mean(mean_epoch_loss)} | Val Loss {np.mean(mean_epoch_loss_val)}")
        if VERBOSE:
            with torch.no_grad():
                plot_noise_prediction(noise[0], predicted_noise[0])
                plot_noise_distribution(noise, predicted_noise)

        torch.save(unet.state_dict(), f"epoch: {epoch}")
# Out:
# ---
# Epoch: 0 | Train Loss 0.17706772830241765 | Val Loss 0.08909450949002536

# %%
unet = UNet(labels=True)
unet.load_state_dict(torch.load(("/content/epoch_ 0"), map_location=torch.device('cpu')),strict=False) # Added map_location argument
# Out:
# <ipython-input-23-997248f4f072>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
unet
# Out:
# UNet(
#   (downsampling): ModuleList(
#     (0): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): Linear(in_features=1, out_features=128, bias=True)
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (final): Conv2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bnorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (time_mlp): Linear(in_features=128, out_features=128, bias=True)
#       (relu): ReLU()
#     )
#     (1): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): Linear(in_features=1, out_features=256, bias=True)
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
NUM_CLASSES = len(classes)
NUM_DISPLAY_IMAGES = 5

# %%
import matplotlib.pyplot as plt

# %%
diffusion_model = DiffusionModel()

# %% [markdown]
# ###Static Post training Quantisation

# %% [markdown]
# ###Helper Functions

# %%
def load_model(model_file):
    model = UNet(labels=True)
    # Explicitly specify map_location to 'cpu' during loading
    state_dict = torch.load(model_file, map_location=torch.device('cpu'),weights_only=True)  # Remove weights_only=True to load all layers
    model.load_state_dict(state_dict)
    model.to('cpu')
    return model

# %%
import torch
import torch.nn as nn
import math
from torch.ao.quantization import QuantStub, DeQuantStub

class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, channels_in, channels_out, time_embedding_dims, labels, num_filters=3, downsample=True):
        super().__init__()

        self.time_embedding_dims = time_embedding_dims
        self.time_embedding = SinusoidalPositionEmbeddings(time_embedding_dims)
        self.labels = labels
        if labels:
            self.label_mlp = nn.Linear(1, channels_out)

        self.downsample = downsample

        if downsample:
            self.conv1 = nn.Conv2d(channels_in, channels_out, num_filters, padding=1)
            self.final = nn.Conv2d(channels_out, channels_out, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(2 * channels_in, channels_out, num_filters, padding=1)
            self.final = nn.ConvTranspose2d(channels_out, channels_out, 4, 2, 1)

        self.bnorm1 = nn.BatchNorm2d(channels_out)
        self.bnorm2 = nn.BatchNorm2d(channels_out)

        self.conv2 = nn.Conv2d(channels_out, channels_out, 3, padding=1)
        self.time_mlp = nn.Linear(time_embedding_dims, channels_out)
        self.relu = nn.ReLU()

    def forward(self, x, t, **kwargs):
        o = self.bnorm1(self.relu(self.conv1(x)))
        o_time = self.relu(self.time_mlp(self.time_embedding(t)))
        o = o + o_time[(..., ) + (None, ) * 2]
        if self.labels:
            label = kwargs.get('labels')
            o_label = self.relu(self.label_mlp(label))
            o = o + o_label[(..., ) + (None, ) * 2]

        o = self.bnorm2(self.relu(self.conv2(o)))

        return self.final(o)
# class Quantizer(nn.Module):
#     def __init__(self, num_bits=8):
#         super().__init__()
#         self.num_bits = num_bits

#     def forward(self, x):
#         # Simple quantization logic for demonstration
#         # You'll likely need to adjust this to your specific needs
#         qmin = 0.
#         qmax = 2.**self.num_bits - 1.
#         min_val = torch.min(x)
#         max_val = torch.max(x)
#         scale = (max_val - min_val) / (qmax - qmin)
#         initial_zero_point = qmin - min_val / scale
#         zero_point = 0  # for simplicity, you can modify for more accurate results
#         q_x = zero_point + torch.round(x / scale)
#         q_x = torch.clamp(q_x, qmin, qmax)
#         return q_x * scale + min_val - zero_point * scale


class UNet(nn.Module):
    def __init__(self, img_channels=3, time_embedding_dims=128, labels=False, sequence_channels=(64, 128, 256, 512, 1024)):
        super().__init__()
        self.time_embedding_dims = time_embedding_dims
        sequence_channels_rev = list(reversed(sequence_channels))
        self.quant = QuantStub()
        self.dequant = DeQuantStub()
        # self.dequant = Quantizer()

        self.downsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels)
                                           for channels_in, channels_out in zip(sequence_channels, sequence_channels[1:])])
        self.upsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels, downsample=False)
                                         for channels_in, channels_out in zip(sequence_channels_rev, sequence_channels_rev[1:])])
        self.conv1 = nn.Conv2d(img_channels, sequence_channels[0], 3, padding=1)
        self.conv2 = nn.Conv2d(sequence_channels[0], img_channels, 1)

    def forward(self, x, t, **kwargs):
        residuals = []
        x = self.quant(x)
        o = self.conv1(x)
        for ds in self.downsampling:
            o = ds(o, t, **kwargs)
            residuals.append(o)
        for us, res in zip(self.upsampling, reversed(residuals)):
            o = us(torch.cat((o, res), dim=1), t, **kwargs)
        o = self.conv2(o)
        return self.dequant(o)

# %%
# Out:
# __main__.UNet

# %%
myModel = load_model('/content/epoch_ 0')
myModel.eval()

# Fuse Conv, bn and relu
# myModel.fuse_model()

# Specify quantization configuration
# Start with simple min/max range estimation and per-tensor quantization of weights
myModel.qconfig = torch.ao.quantization.default_qconfig
print(myModel.qconfig)
torch.ao.quantization.prepare(myModel, inplace=True)
# Out:
# QConfig(activation=functools.partial(<class 'torch.ao.quantization.observer.MinMaxObserver'>, quant_min=0, quant_max=127){}, weight=functools.partial(<class 'torch.ao.quantization.observer.MinMaxObserver'>, dtype=torch.qint8, qscheme=torch.per_tensor_symmetric){})
# UNet(
#   (quant): QuantStub(
#     (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#   )
#   (dequant): DeQuantStub()
#   (downsampling): ModuleList(
#     (0): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): Linear(
#         in_features=1, out_features=128, bias=True
#         (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#       )
#       (conv1): Conv2d(
#         64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation_post_process): MinMaxObserver(min_val=inf, max_val=-inf)
#       )
#       (final): Conv2d(
#         128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1)
# ...

# %%
import torch
import torch.ao.quantization as quant
import matplotlib.pyplot as plt

# Define model
unet = UNet(labels=True)

# Load model weights (using weights_only=True if available)
try:
    unet.load_state_dict(torch.load('/content/epoch_ 0', map_location=torch.device('cpu'), weights_only=True), strict=False)
except TypeError:
    # Fallback for older PyTorch versions
    unet.load_state_dict(torch.load("/content/epoch_ 0", map_location=torch.device('cpu')), strict=False)

# Set model to evaluation mode
unet.eval()

# Attach a quantization configuration
unet.qconfig = quant.default_qconfig  # Use the default configuration

# Prepare model for quantization
quant.prepare(unet, inplace=True)

# Synthetic data calibration
classes = ('plane', 'car')
NUM_CLASSES = len(classes)
NUM_DISPLAY_IMAGES = 2
IMAGE_SHAPE = (32, 32)  # Replace with the actual input shape of your model

torch.manual_seed(16)

# Visualization setup
with torch.no_grad():
  plt.figure(figsize=(15, 15))
  f, ax = plt.subplots(NUM_CLASSES, NUM_DISPLAY_IMAGES, figsize=(100, 100))

  for c in range(NUM_CLASSES):
      imgs = torch.randn((NUM_DISPLAY_IMAGES, 3) + IMAGE_SHAPE).to(device='cpu')
      for i in reversed(range(diffusion_model.timesteps)):
          t = torch.full((1,), i, dtype=torch.long, device='cpu')
          labels = torch.tensor([c] * NUM_DISPLAY_IMAGES).reshape(NUM_DISPLAY_IMAGES, 1).float().to(device='cpu')
          # Forward pass for calibration
          imgs = diffusion_model.backward(x=imgs, t=t, model=unet, labels=labels)
      for idx, img in enumerate(imgs):
          ax[c][idx].imshow(reverse_transform(img))
          ax[c][idx].set_title(f"Class: {classes[c]}", fontsize=100)

  plt.show()
# Convert the model to finalize quantization
quant.convert(unet, inplace=True)
# Out:
# UNet(
#   (quant): Quantize(scale=tensor([0.0743]), zero_point=tensor([64]), dtype=torch.quint8)
#   (dequant): DeQuantize()
#   (downsampling): ModuleList(
#     (0): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): QuantizedLinear(in_features=1, out_features=128, scale=0.02794582024216652, zero_point=65, qscheme=torch.per_tensor_affine)
#       (conv1): QuantizedConv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.04923750087618828, zero_point=60, padding=(1, 1))
#       (final): QuantizedConv2d(128, 128, kernel_size=(4, 4), stride=(2, 2), scale=0.10808123648166656, zero_point=64, padding=(1, 1))
#       (bnorm1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bnorm2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ###Starting Quantisation Aware Training

# %%
def load_model(model_file):
    model = UNet(labels=True)
    # Explicitly specify map_location to 'cpu' during loading
    state_dict = torch.load(model_file, map_location=torch.device('cpu'),weights_only=True)  # Remove weights_only=True to load all layers
    model.load_state_dict(state_dict)
    model.to('cpu')
    return model

# %%
import torch
import torch.nn as nn
import math
from torch.ao.quantization import QuantStub, DeQuantStub

class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, channels_in, channels_out, time_embedding_dims, labels, num_filters=3, downsample=True):
        super().__init__()

        self.time_embedding_dims = time_embedding_dims
        self.time_embedding = SinusoidalPositionEmbeddings(time_embedding_dims)
        self.labels = labels
        if labels:
            self.label_mlp = nn.Linear(1, channels_out)

        self.downsample = downsample

        if downsample:
            self.conv1 = nn.Conv2d(channels_in, channels_out, num_filters, padding=1)
            self.final = nn.Conv2d(channels_out, channels_out, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(2 * channels_in, channels_out, num_filters, padding=1)
            self.final = nn.ConvTranspose2d(channels_out, channels_out, 4, 2, 1)

        self.bnorm1 = nn.BatchNorm2d(channels_out)
        self.bnorm2 = nn.BatchNorm2d(channels_out)

        self.conv2 = nn.Conv2d(channels_out, channels_out, 3, padding=1)
        self.time_mlp = nn.Linear(time_embedding_dims, channels_out)
        self.relu = nn.ReLU()

    def forward(self, x, t, **kwargs):
        o = self.bnorm1(self.relu(self.conv1(x)))
        o_time = self.relu(self.time_mlp(self.time_embedding(t)))
        o = o + o_time[(..., ) + (None, ) * 2]
        if self.labels:
            label = kwargs.get('labels')
            o_label = self.relu(self.label_mlp(label))
            o = o + o_label[(..., ) + (None, ) * 2]

        o = self.bnorm2(self.relu(self.conv2(o)))

        return self.final(o)
# class Quantizer(nn.Module):
#     def __init__(self, num_bits=8):
#         super().__init__()
#         self.num_bits = num_bits

#     def forward(self, x):
#         # Simple quantization logic for demonstration
#         # You'll likely need to adjust this to your specific needs
#         qmin = 0.
#         qmax = 2.**self.num_bits - 1.
#         min_val = torch.min(x)
#         max_val = torch.max(x)
#         scale = (max_val - min_val) / (qmax - qmin)
#         initial_zero_point = qmin - min_val / scale
#         zero_point = 0  # for simplicity, you can modify for more accurate results
#         q_x = zero_point + torch.round(x / scale)
#         q_x = torch.clamp(q_x, qmin, qmax)
#         return q_x * scale + min_val - zero_point * scale


class UNet(nn.Module):
    def __init__(self, img_channels=3, time_embedding_dims=128, labels=False, sequence_channels=(64, 128, 256, 512, 1024)):
        super().__init__()
        self.time_embedding_dims = time_embedding_dims
        sequence_channels_rev = list(reversed(sequence_channels))
        self.quant = QuantStub()
        self.dequant = DeQuantStub()
        # self.dequant = Quantizer()

        self.downsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels)
                                           for channels_in, channels_out in zip(sequence_channels, sequence_channels[1:])])
        self.upsampling = nn.ModuleList([Block(channels_in, channels_out, time_embedding_dims, labels, downsample=False)
                                         for channels_in, channels_out in zip(sequence_channels_rev, sequence_channels_rev[1:])])
        self.conv1 = nn.Conv2d(img_channels, sequence_channels[0], 3, padding=1)
        self.conv2 = nn.Conv2d(sequence_channels[0], img_channels, 1)

    def forward(self, x, t, **kwargs):
        residuals = []
        x = self.quant(x)
        o = self.conv1(x)
        for ds in self.downsampling:
            o = ds(o, t, **kwargs)
            residuals.append(o)
        for us, res in zip(self.upsampling, reversed(residuals)):
            o = us(torch.cat((o, res), dim=1), t, **kwargs)
        o = self.conv2(o)
        return self.dequant(o)

# %%
myModel = load_model('/content/epoch_ 0')
myModel.eval()

# Fuse Conv, bn and relu
# myModel.fuse_model()

# Specify quantization configuration
# Start with simple min/max range estimation and per-tensor quantization of weights
myModel.qconfig = torch.ao.quantization.get_default_qat_qconfig('x86')
print(myModel.qconfig)
# torch.ao.quantization.prepare_qat(myModel, inplace=True)
# Out:
# QConfig(activation=functools.partial(<class 'torch.ao.quantization.fake_quantize.FusedMovingAvgObsFakeQuantize'>, observer=<class 'torch.ao.quantization.observer.MovingAverageMinMaxObserver'>, quant_min=0, quant_max=255, reduce_range=True){}, weight=functools.partial(<class 'torch.ao.quantization.fake_quantize.FusedMovingAvgObsFakeQuantize'>, observer=<class 'torch.ao.quantization.observer.MovingAveragePerChannelMinMaxObserver'>, quant_min=-128, quant_max=127, dtype=torch.qint8, qscheme=torch.per_channel_symmetric){})

# %%
myModel
# Out:
# UNet(
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
#   (downsampling): ModuleList(
#     (0): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): Linear(in_features=1, out_features=128, bias=True)
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (final): Conv2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bnorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (time_mlp): Linear(in_features=128, out_features=128, bias=True)
#       (relu): ReLU()
#     )
#     (1): Block(
#       (time_embedding): SinusoidalPositionEmbeddings()
#       (label_mlp): Linear(in_features=1, out_features=256, bias=True)
# ...

# %%
device = 'cpu'

# %%
BATCH_SIZE = 256
NO_EPOCHS = 5
PRINT_FREQUENCY = 10
LR = 0.001
VERBOSE = False

# unet = myModel(labels=True)
# unet.to(device)
# optimizer = torch.optim.Adam(unet.parameters(), lr=LR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-efa0e026d4c0> in <cell line: 7>()
#       5 VERBOSE = False
#       6
# ----> 7 unet = myModel(labels=True)
#       8 unet.to(device)
#       9 optimizer = torch.optim.Adam(unet.parameters(), lr=LR)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
NO_EPOCHS
# Out:
# 5

# %%
def train_one_epoch(device, ntrain_batches):
    mean_epoch_loss = []
    mean_epoch_loss_val = []
    cnt = 0
    for batch, label in trainloader:
        cnt+=1
        t = torch.randint(0, diffusion_model.timesteps, (BATCH_SIZE,)).long().to(device)
        batch = batch.to(device)
        batch_noisy, noise = diffusion_model.forward(batch, t, device)
        predicted_noise = myModel(batch_noisy, t, labels = label.reshape(-1,1).float().to(device))

        optimizer.zero_grad()
        loss = torch.nn.functional.mse_loss(noise, predicted_noise)
        mean_epoch_loss.append(loss.item())
        loss.backward()
        optimizer.step()

    for batch, label in testloader:
        cnt+=1
        t = torch.randint(0, diffusion_model.timesteps, (BATCH_SIZE,)).long().to(device)
        batch = batch.to(device)

        batch_noisy, noise = diffusion_model.forward(batch, t, device)
        predicted_noise = myModel(batch_noisy, t, labels = label.reshape(-1,1).float().to(device))

        loss = torch.nn.functional.mse_loss(noise, predicted_noise)
        mean_epoch_loss_val.append(loss.item())

    if epoch % PRINT_FREQUENCY == 0:
        print('---')
        print(f"Epoch: {epoch} | Train Loss {np.mean(mean_epoch_loss)} | Val Loss {np.mean(mean_epoch_loss_val)}")
        if VERBOSE:
            with torch.no_grad():
                plot_noise_prediction(noise[0], predicted_noise[0])
                plot_noise_distribution(noise, predicted_noise)

        torch.save(myModel.state_dict(), f"epoch: {epoch}")
    if cnt>=ntrain_batches:
        # break
        return mean_epoch_loss, mean_epoch_loss_val

# %%
num_train_batches = 2  # Number of training batches to process per epoch
num_epochs = 3  # Total number of epochs
PRINT_FREQUENCY = 1  # Frequency for printing training updates

for nepoch in range(num_epochs):
    print(f"\nEpoch {nepoch + 1}/{num_epochs}: Training...")

    # Train for one epoch (includes train and test loss calculation)
    train_losses, val_losses = train_one_epoch(
        device=torch.device('cpu'),
        ntrain_batches=num_train_batches
    )

    # Freeze observers after the 3rd epoch for QAT
    if nepoch > 2:
        qat_model.apply(torch.ao.quantization.disable_observer)

    # Freeze BatchNorm statistics after the 2nd epoch
    if nepoch > 1:
        qat_model.apply(torch.nn.intrinsic.qat.freeze_bn_stats)

    # Convert the QAT model to a quantized model after each epoch
    quantized_model = torch.ao.quantization.convert(qat_model.eval(), inplace=False)
    quantized_model.eval()

    # Log the results for the current epoch
    print(f"Epoch {nepoch + 1}: Train Loss {np.mean(train_losses):.5f}, Val Loss {np.mean(val_losses):.5f}")

    # Check performance of the quantized model if necessary
    if nepoch % PRINT_FREQUENCY == 0:
        print(f"\nEpoch {nepoch + 1}: Checking quantized model...")
        quantized_val_losses = []
        with torch.no_grad():
            for batch, label in testloader:
                batch = batch.to(torch.device('cpu'))
                label = label.to(torch.device('cpu'))

                # Perform evaluation
                t = torch.randint(0, diffusion_model.timesteps, (batch.size(0),)).long().to(torch.device('cpu'))
                batch_noisy, noise = diffusion_model.forward(batch, t, device='cpu')
                predicted_noise = quantized_model(batch_noisy, t, labels=label.reshape(-1, 1).float())
                loss = torch.nn.functional.mse_loss(noise, predicted_noise)
                quantized_val_losses.append(loss.item())

        # Log quantized model's validation loss
        print(f"Epoch {nepoch + 1}: Quantized Val Loss {np.mean(quantized_val_losses):.5f}")
# Out:
# Epoch 1/3: Training...
